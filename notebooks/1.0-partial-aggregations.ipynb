# %% [markdown]
# # Aggregations of Partial History
# People change over time, perhaps using only a subset of the history supplied in our aggregations can boost our model score.

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 

# %matplotlib inline
# Out:
# /home/david/.local/lib/python2.7/site-packages/pandas/_libs/__init__.py:4: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .tslib import iNaT, NaT, Timestamp, Timedelta, OutOfBoundsDatetime
# /home/david/.local/lib/python2.7/site-packages/pandas/__init__.py:26: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (hashtable as _hashtable,
# /home/david/.local/lib/python2.7/site-packages/pandas/core/dtypes/common.py:6: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import algos, lib
# /home/david/.local/lib/python2.7/site-packages/pandas/core/util/hashing.py:7: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import hashing, tslib
# /home/david/.local/lib/python2.7/site-packages/pandas/core/indexes/base.py:7: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (lib, index as libindex, tslib as libts,
# /home/david/.local/lib/python2.7/site-packages/pandas/tseries/offsets.py:21: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   import pandas._libs.tslibs.offsets as liboffsets
# /home/david/.local/lib/python2.7/site-packages/pandas/core/ops.py:16: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import algos as libalgos, ops as libops
# /home/david/.local/lib/python2.7/site-packages/pandas/core/indexes/interval.py:32: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs.interval import (
# /home/david/.local/lib/python2.7/site-packages/pandas/core/internals.py:14: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import internals as libinternals
# /home/david/.local/lib/python2.7/site-packages/pandas/core/sparse/array.py:33: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   import pandas._libs.sparse as splib
# /home/david/.local/lib/python2.7/site-packages/pandas/core/window.py:36: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   import pandas._libs.window as _window
# /home/david/.local/lib/python2.7/site-packages/pandas/core/groupby/groupby.py:68: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (lib, reduction,
# /home/david/.local/lib/python2.7/site-packages/pandas/core/reshape/reshape.py:30: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import algos as _algos, reshape as _reshape
# /home/david/.local/lib/python2.7/site-packages/pandas/io/parsers.py:45: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   import pandas._libs.parsers as parsers
# /home/david/.local/lib/python2.7/site-packages/pandas/io/pytables.py:50: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import algos, lib, writers as libwriters

# %% [markdown]
# ### Setup Data
# First, I will load the data for the main application as well as the credit card history into two pandas dataframes.  Pandas will be used to do the heavy lifting of the aggregations.  For this work, I will select a subset of the entire dataset to make things easier to work with.

# %%
app_data = pd.read_csv('../data/raw/application_train.csv')
cc_data = pd.read_csv('../data/raw/credit_card_balance.csv')

# %%
N_TEST_USERS = 100000
test_user_ids = np.random.choice(app_data['SK_ID_CURR'], N_TEST_USERS)
app_data = app_data.loc[app_data['SK_ID_CURR'].isin(test_user_ids)]
cc_data = cc_data.loc[cc_data['SK_ID_CURR'].isin(test_user_ids)]

# %%
app_data.head()
# Out:
#     SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 1       100003       0         Cash loans           F            N
# 2       100004       0    Revolving loans           M            Y
# 9       100012       0    Revolving loans           M            N
# 11      100015       0         Cash loans           F            N
# 15      100019       0         Cash loans           M            Y
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 1                N             0        270000.000   1293502.5      35698.5
# 2                Y             0         67500.000    135000.0       6750.0
# 9                Y             0        135000.000    405000.0      20250.0
# 11               Y             0         38419.155    148365.0      10678.5
# 15               Y             0        157500.000    299772.0      20160.0
#
#                ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# 1              ...                             0                0
# 2              ...                             0                0
# 9              ...                             0                0
# 11             ...                             0                0
# 15             ...                             0                0
#
#    FLAG_DOCUMENT_20 FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR  \
# 1                 0                0                        0.0
# 2                 0                0                        0.0
# 9                 0                0                        NaN
# 11                0                0                        0.0
# 15                0                0                        0.0
#
#    AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# 1                        0.0                         0.0
# 2                        0.0                         0.0
# 9                        NaN                         NaN
# 11                       0.0                         0.0
# 15                       0.0                         0.0
#
#     AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# 1                         0.0                        0.0
# 2                         0.0                        0.0
# 9                         NaN                        NaN
# 11                        0.0                        0.0
# 15                        0.0                        0.0
#
#     AMT_REQ_CREDIT_BUREAU_YEAR
# 1                          0.0
# 2                          0.0
# 9                          NaN
# 11                         2.0
# 15                         1.0
#
# [5 rows x 122 columns]

# %%
cc_data.head()
# Out:
#     SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 4      1891521      126868              -1   453919.455
# 9      1235299      203885              -5   201261.195
# 13     1441883      171537              -5        0.000
# 14     1864742      303581              -1        0.000
# 18     2016842      302450              -3        0.000
#
#     AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  AMT_DRAWINGS_CURRENT  \
# 4                    450000                       0.0               11547.0
# 9                    225000                   76500.0              111026.7
# 13                   270000                       0.0                   0.0
# 14                    45000                       0.0                   0.0
# 18                        0                       0.0                   0.0
#
#     AMT_DRAWINGS_OTHER_CURRENT  AMT_DRAWINGS_POS_CURRENT  \
# 4                          0.0                   11547.0
# 9                          0.0                   34526.7
# 13                         0.0                       0.0
# 14                         0.0                       0.0
# 18                         0.0                       0.0
#
#     AMT_INST_MIN_REGULARITY     ...      AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  \
# 4                  22924.89     ...         453919.455            453919.455
# 9                   6338.34     ...         197224.695            197224.695
# 13                 12218.49     ...              0.000                 0.000
# 14                     0.00     ...              0.000                 0.000
# 18                     0.00     ...              0.000                 0.000
#
#     CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# 4                        0.0                     1
# 9                        3.0                     9
# 13                       0.0                     0
# 14                       0.0                     0
# 18                       0.0                     0
#
#     CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# 4                          0.0                       1.0
# 9                          0.0                       6.0
# 13                         0.0                       0.0
# 14                         0.0                       0.0
# 18                         0.0                       0.0
#
#     CNT_INSTALMENT_MATURE_CUM  NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 4                       101.0                Active       0           0
# 9                        38.0                Active       0           0
# 13                        2.0                Active       0           0
# 14                       59.0                Active       0           0
# 18                        2.0             Completed       0           0
#
# [5 rows x 23 columns]

# %%
def last_k(data, agg_func, k):
    return agg_func(data[:k])

def last_6_mean(data):
    return last_k(data, np.mean, 6)

def last_12_mean(data):
    return last_k(data, np.mean, 12)

def last_18_mean(data):
    return last_k(data, np.mean, 18)

def last_24_mean(data):
    return last_k(data, np.mean, 24)

# %%
import time 
aggs = {
    'AMT_BALANCE':[last_6_mean, last_12_mean, last_18_mean, last_24_mean]
}

t_start = time.time()
cc_agg = cc_data.groupby('SK_ID_CURR').agg(aggs)
print('Finshined: ', time.time()-t_start)
# Out:
# ('Finshined: ', 13.81001591682434)

# %%
colname = lambda x, y: 'CC_' + x + '_' + y.upper() 
new_cols = [colname(c[0],c[1]) for c in list(cc_agg.columns)]
cc_agg.columns = new_cols
cc_agg.head(4)
# Out:
#             CC_AMT_BALANCE_LAST_6_MEAN  CC_AMT_BALANCE_LAST_12_MEAN  \
# SK_ID_CURR
# 100048                      43183.4475                  50084.79375
# 100050                          0.0000                      0.00000
# 100059                          0.0000                      0.00000
# 100082                       2606.7825                  22280.41500
#
#             CC_AMT_BALANCE_LAST_18_MEAN  CC_AMT_BALANCE_LAST_24_MEAN
# SK_ID_CURR
# 100048                        53802.080                  54142.44375
# 100050                            0.000                      0.00000
# 100059                            0.000                      0.00000
# 100082                        14871.005                  16599.13500

# %%
data = app_data.join(cc_agg)
data.head()
# Out:
#     SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 1       100003       0         Cash loans           F            N
# 2       100004       0    Revolving loans           M            Y
# 9       100012       0    Revolving loans           M            N
# 11      100015       0         Cash loans           F            N
# 15      100019       0         Cash loans           M            Y
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 1                N             0        270000.000   1293502.5      35698.5
# 2                Y             0         67500.000    135000.0       6750.0
# 9                Y             0        135000.000    405000.0      20250.0
# 11               Y             0         38419.155    148365.0      10678.5
# 15               Y             0        157500.000    299772.0      20160.0
#
#                ...               AMT_REQ_CREDIT_BUREAU_HOUR  \
# 1              ...                                      0.0
# 2              ...                                      0.0
# 9              ...                                      NaN
# 11             ...                                      0.0
# 15             ...                                      0.0
#
#    AMT_REQ_CREDIT_BUREAU_DAY AMT_REQ_CREDIT_BUREAU_WEEK  \
# 1                        0.0                        0.0
# 2                        0.0                        0.0
# 9                        NaN                        NaN
# 11                       0.0                        0.0
# 15                       0.0                        0.0
#
#    AMT_REQ_CREDIT_BUREAU_MON AMT_REQ_CREDIT_BUREAU_QRT  \
# 1                        0.0                       0.0
# 2                        0.0                       0.0
# 9                        NaN                       NaN
# 11                       0.0                       0.0
# 15                       0.0                       0.0
#
#    AMT_REQ_CREDIT_BUREAU_YEAR  CC_AMT_BALANCE_LAST_6_MEAN  \
# 1                         0.0                         NaN
# 2                         0.0                         NaN
# 9                         NaN                         NaN
# 11                        2.0                         NaN
# 15                        1.0                         NaN
#
#     CC_AMT_BALANCE_LAST_12_MEAN  CC_AMT_BALANCE_LAST_18_MEAN  \
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 9                           NaN                          NaN
# 11                          NaN                          NaN
# 15                          NaN                          NaN
#
#     CC_AMT_BALANCE_LAST_24_MEAN
# 1                           NaN
# 2                           NaN
# 9                           NaN
# 11                          NaN
# 15                          NaN
#
# [5 rows x 126 columns]

# %%
data.corr()['TARGET'].sort_values(ascending=True)
# Out:
# EXT_SOURCE_3                  -0.180616
# EXT_SOURCE_2                  -0.160529
# EXT_SOURCE_1                  -0.155786
# FLOORSMAX_AVG                 -0.048150
# DAYS_EMPLOYED                 -0.047948
# FLOORSMAX_MEDI                -0.047586
# FLOORSMAX_MODE                -0.047193
# AMT_GOODS_PRICE               -0.038642
# REGION_POPULATION_RELATIVE    -0.036330
# TOTALAREA_MODE                -0.035249
# ELEVATORS_AVG                 -0.035099
# ELEVATORS_MEDI                -0.034905
# LIVINGAREA_AVG                -0.034661
# LIVINGAREA_MEDI               -0.034366
# ELEVATORS_MODE                -0.033079
# APARTMENTS_AVG                -0.032645
# LIVINGAREA_MODE               -0.032048
# APARTMENTS_MEDI               -0.031950
# FLOORSMIN_AVG                 -0.030414
# APARTMENTS_MODE               -0.030223
# FLOORSMIN_MEDI                -0.030053
# FLOORSMIN_MODE                -0.029398
# AMT_CREDIT                    -0.029143
# FLAG_DOCUMENT_6               -0.029140
# YEARS_BUILD_MEDI              -0.026768
# BASEMENTAREA_AVG              -0.026601
# YEARS_BUILD_AVG               -0.026377
# BASEMENTAREA_MEDI             -0.025961
# YEARS_BUILD_MODE              -0.025237
# BASEMENTAREA_MODE             -0.024387
#                                  ...
# FLAG_DOCUMENT_7                0.003575
# FLAG_EMAIL                     0.004418
# NONLIVINGAPARTMENTS_AVG        0.004653
# NONLIVINGAPARTMENTS_MEDI       0.004930
# REG_REGION_NOT_LIVE_REGION     0.005489
# NONLIVINGAPARTMENTS_MODE       0.006369
# LIVE_REGION_NOT_WORK_REGION    0.006774
# OBS_60_CNT_SOCIAL_CIRCLE       0.007498
# OBS_30_CNT_SOCIAL_CIRCLE       0.007782
# CNT_FAM_MEMBERS                0.009291
# REG_REGION_NOT_WORK_REGION     0.011044
# AMT_REQ_CREDIT_BUREAU_YEAR     0.015127
# CNT_CHILDREN                   0.018547
# DEF_60_CNT_SOCIAL_CIRCLE       0.028796
# FLAG_WORK_PHONE                0.029353
# DEF_30_CNT_SOCIAL_CIRCLE       0.030151
# OWN_CAR_AGE                    0.032954
# LIVE_CITY_NOT_WORK_CITY        0.034527
# DAYS_REGISTRATION              0.039797
# FLAG_DOCUMENT_3                0.042207
# REG_CITY_NOT_LIVE_CITY         0.047532
# FLAG_EMP_PHONE                 0.048936
# DAYS_ID_PUBLISH                0.051505
# REG_CITY_NOT_WORK_CITY         0.052080
# DAYS_LAST_PHONE_CHANGE         0.056244
# REGION_RATING_CLIENT           0.058979
# REGION_RATING_CLIENT_W_CITY    0.061496
# DAYS_BIRTH                     0.080062
# TARGET                         1.000000
# FLAG_DOCUMENT_12                    NaN
# Name: TARGET, Length: 110, dtype: float64
