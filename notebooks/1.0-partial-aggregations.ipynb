# %% [markdown]
# # Aggregations of Partial History
# People change over time, perhaps using only a subset of the history supplied in our aggregations can boost our model score.

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 

# %matplotlib inline

# %% [markdown]
# ### Setup Data
# First, I will load the data for the main application as well as the credit card history into two pandas dataframes.  Pandas will be used to do the heavy lifting of the aggregations.  For this work, I will select a subset of the entire dataset to make things easier to work with.

# %%
app_data = pd.read_csv('../data/raw/application_train.csv')
cc_data = pd.read_csv('../data/raw/credit_card_balance.csv')

# %%
N_TEST_USERS = 1000
test_user_ids = np.random.choice(app_data['SK_ID_CURR'], N_TEST_USERS)
app_data = app_data.loc[app_data['SK_ID_CURR'].isin(test_user_ids)]
cc_data = cc_data.loc[cc_data['SK_ID_CURR'].isin(test_user_ids)]

# %%
app_data.head()
# Out:
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 1294      101523       0         Cash loans           F            N
# 1594      101866       0         Cash loans           M            N
# 1857      102178       0         Cash loans           F            N
# 2214      102598       0         Cash loans           M            Y
# 2454      102861       0         Cash loans           F            Y
#
#      FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 1294               Y             0          135000.0    505642.5      25947.0
# 1594               N             0          180000.0   1609272.0      46251.0
# 1857               N             0          117000.0    239850.0      25830.0
# 2214               Y             0          157500.0    404325.0      22063.5
# 2454               Y             0          202500.0   1800000.0      49500.0
#
#                  ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# 1294             ...                             0                0
# 1594             ...                             0                0
# 1857             ...                             0                0
# 2214             ...                             0                0
# 2454             ...                             0                0
#
#      FLAG_DOCUMENT_20 FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR  \
# 1294                0                0                        NaN
# 1594                0                0                        0.0
# 1857                0                0                        0.0
# 2214                0                0                        0.0
# 2454                0                0                        0.0
#
#      AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# 1294                       NaN                         NaN
# 1594                       0.0                         0.0
# 1857                       0.0                         0.0
# 2214                       0.0                         0.0
# 2454                       0.0                         0.0
#
#       AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# 1294                        NaN                        NaN
# 1594                        0.0                        0.0
# 1857                        0.0                        0.0
# 2214                        0.0                        1.0
# 2454                        0.0                        0.0
#
#       AMT_REQ_CREDIT_BUREAU_YEAR
# 1294                         NaN
# 1594                         3.0
# 1857                         2.0
# 2214                         3.0
# 2454                         3.0
#
# [5 rows x 122 columns]

# %%
cc_data.head()
# Out:
#       SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 468      1840380      402158              -5   430273.755
# 522      2386359      147939              -1    33966.585
# 821      2309885      251971              -1        0.000
# 1442     1163691      444478              -4        0.000
# 1527     1678063      147939              -1        0.000
#
#       AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  AMT_DRAWINGS_CURRENT  \
# 468                    450000                       0.0             22666.545
# 522                    135000                       0.0             54050.130
# 821                         0                       0.0                 0.000
# 1442                        0                       0.0                 0.000
# 1527                        0                       0.0                 0.000
#
#       AMT_DRAWINGS_OTHER_CURRENT  AMT_DRAWINGS_POS_CURRENT  \
# 468                          0.0                 22666.545
# 522                          0.0                 54050.130
# 821                          0.0                     0.000
# 1442                         0.0                     0.000
# 1527                         0.0                     0.000
#
#       AMT_INST_MIN_REGULARITY     ...      AMT_RECIVABLE  \
# 468                 22083.075     ...         430273.755
# 522                   188.595     ...          33966.585
# 821                     0.000     ...              0.000
# 1442                    0.000     ...              0.000
# 1527                    0.000     ...              0.000
#
#       AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# 468             430273.755                       0.0                     7
# 522              33966.585                       0.0                    33
# 821                  0.000                       0.0                     0
# 1442                 0.000                       0.0                     0
# 1527                 0.000                       0.0                     0
#
#       CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# 468                          0.0                       7.0
# 522                          0.0                      33.0
# 821                          0.0                       0.0
# 1442                         0.0                       0.0
# 1527                         0.0                       0.0
#
#       CNT_INSTALMENT_MATURE_CUM  NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 468                        22.0                Active       0           0
# 522                         3.0                Active       0           0
# 821                         5.0             Completed       0           0
# 1442                        3.0             Completed       0           0
# 1527                        9.0             Completed       0           0
#
# [5 rows x 23 columns]

# %%
def last_k(data, agg_func, k):
    return agg_func(data[:k])

def last_6_mean(data):
    return last_k(data, np.mean, 6)

def last_12_mean(data):
    return last_k(data, np.mean, 12)

def last_18_mean(data):
    return last_k(data, np.mean, 18)

def last_24_mean(data):
    return last_k(data, np.mean, 24)

# %%
import time 
aggs = {
    'AMT_BALANCE':[last_6_mean, last_12_mean, last_18_mean, last_24_mean]
}

t_start = time.time()
cc_agg = cc_data.sort_values(['SK_ID_CURR', 'MONTHS_BALANCE']).groupby('SK_ID_CURR').agg(aggs)
print('Finshined: ', time.time()-t_start)
# Out:
# ('Finshined: ', 0.25685787200927734)

# %%
colname = lambda x, y: 'CC_' + x + '_' + y.upper() 
new_cols = [colname(c[0],c[1]) for c in list(cc_agg.columns)]
cc_agg.columns = new_cols
cc_agg.head(4)
# Out:
#             CC_AMT_BALANCE_LAST_6_MEAN  CC_AMT_BALANCE_LAST_12_MEAN  \
# SK_ID_CURR
# 101866                      339419.160                  391110.2325
# 102981                           0.000                       0.0000
# 103528                      471165.525                  422742.1950
# 104476                       85174.260                   61496.5050
#
#             CC_AMT_BALANCE_LAST_18_MEAN  CC_AMT_BALANCE_LAST_24_MEAN
# SK_ID_CURR
# 101866                      399228.7000                390295.033125
# 102981                           0.0000                     0.000000
# 103528                      425819.2950                425819.295000
# 104476                       43191.0075                 34125.577500

# %%
data = app_data.join(cc_agg)
data.head()
# Out:
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 1294      101523       0         Cash loans           F            N
# 1594      101866       0         Cash loans           M            N
# 1857      102178       0         Cash loans           F            N
# 2214      102598       0         Cash loans           M            Y
# 2454      102861       0         Cash loans           F            Y
#
#      FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 1294               Y             0          135000.0    505642.5      25947.0
# 1594               N             0          180000.0   1609272.0      46251.0
# 1857               N             0          117000.0    239850.0      25830.0
# 2214               Y             0          157500.0    404325.0      22063.5
# 2454               Y             0          202500.0   1800000.0      49500.0
#
#                  ...               AMT_REQ_CREDIT_BUREAU_HOUR  \
# 1294             ...                                      NaN
# 1594             ...                                      0.0
# 1857             ...                                      0.0
# 2214             ...                                      0.0
# 2454             ...                                      0.0
#
#      AMT_REQ_CREDIT_BUREAU_DAY AMT_REQ_CREDIT_BUREAU_WEEK  \
# 1294                       NaN                        NaN
# 1594                       0.0                        0.0
# 1857                       0.0                        0.0
# 2214                       0.0                        0.0
# 2454                       0.0                        0.0
#
#      AMT_REQ_CREDIT_BUREAU_MON AMT_REQ_CREDIT_BUREAU_QRT  \
# 1294                       NaN                       NaN
# 1594                       0.0                       0.0
# 1857                       0.0                       0.0
# 2214                       0.0                       1.0
# 2454                       0.0                       0.0
#
#      AMT_REQ_CREDIT_BUREAU_YEAR  CC_AMT_BALANCE_LAST_6_MEAN  \
# 1294                        NaN                         NaN
# 1594                        3.0                         NaN
# 1857                        2.0                         NaN
# 2214                        3.0                         NaN
# 2454                        3.0                         NaN
#
#       CC_AMT_BALANCE_LAST_12_MEAN  CC_AMT_BALANCE_LAST_18_MEAN  \
# 1294                          NaN                          NaN
# 1594                          NaN                          NaN
# 1857                          NaN                          NaN
# 2214                          NaN                          NaN
# 2454                          NaN                          NaN
#
#       CC_AMT_BALANCE_LAST_24_MEAN
# 1294                          NaN
# 1594                          NaN
# 1857                          NaN
# 2214                          NaN
# 2454                          NaN
#
# [5 rows x 126 columns]

# %%
data.corr()['TARGET'].sort_values(ascending=True)
# Out:
# EXT_SOURCE_2                  -0.199689
# EXT_SOURCE_3                  -0.198864
# EXT_SOURCE_1                  -0.191741
# REGION_POPULATION_RELATIVE    -0.074213
# YEARS_BUILD_MODE              -0.066560
# NONLIVINGAPARTMENTS_MODE      -0.064251
# NONLIVINGAPARTMENTS_AVG       -0.060545
# NONLIVINGAPARTMENTS_MEDI      -0.058809
# YEARS_BUILD_MEDI              -0.057087
# YEARS_BUILD_AVG               -0.056849
# FLAG_DOCUMENT_6               -0.049479
# FLAG_EMAIL                    -0.049376
# FLOORSMAX_AVG                 -0.048811
# FLOORSMAX_MEDI                -0.047792
# LIVINGAREA_MEDI               -0.047409
# LIVINGAREA_AVG                -0.046811
# AMT_GOODS_PRICE               -0.046088
# FLOORSMAX_MODE                -0.044949
# DAYS_EMPLOYED                 -0.043866
# AMT_INCOME_TOTAL              -0.042843
# AMT_CREDIT                    -0.040092
# FLAG_PHONE                    -0.040031
# FLAG_DOCUMENT_5               -0.039694
# LIVINGAREA_MODE               -0.039170
# AMT_REQ_CREDIT_BUREAU_WEEK    -0.037926
# AMT_REQ_CREDIT_BUREAU_QRT     -0.035738
# FLOORSMIN_MODE                -0.034294
# FLOORSMIN_AVG                 -0.032847
# FLOORSMIN_MEDI                -0.032722
# TOTALAREA_MODE                -0.028421
#                                  ...
# LIVINGAPARTMENTS_MEDI          0.032215
# ENTRANCES_MODE                 0.033502
# LIVINGAPARTMENTS_MODE          0.035850
# COMMONAREA_AVG                 0.036199
# COMMONAREA_MEDI                0.036993
# LIVE_CITY_NOT_WORK_CITY        0.043215
# FLAG_EMP_PHONE                 0.045212
# REG_CITY_NOT_WORK_CITY         0.047015
# FLAG_DOCUMENT_16               0.050575
# DAYS_LAST_PHONE_CHANGE         0.065666
# DAYS_REGISTRATION              0.073941
# FLAG_DOCUMENT_3                0.077554
# REGION_RATING_CLIENT           0.091321
# REGION_RATING_CLIENT_W_CITY    0.097917
# DAYS_BIRTH                     0.105790
# OWN_CAR_AGE                    0.245010
# TARGET                         1.000000
# FLAG_MOBIL                          NaN
# FLAG_CONT_MOBILE                    NaN
# FLAG_DOCUMENT_2                     NaN
# FLAG_DOCUMENT_4                     NaN
# FLAG_DOCUMENT_7                     NaN
# FLAG_DOCUMENT_10                    NaN
# FLAG_DOCUMENT_12                    NaN
# FLAG_DOCUMENT_15                    NaN
# FLAG_DOCUMENT_17                    NaN
# CC_AMT_BALANCE_LAST_6_MEAN          NaN
# CC_AMT_BALANCE_LAST_12_MEAN         NaN
# CC_AMT_BALANCE_LAST_18_MEAN         NaN
# CC_AMT_BALANCE_LAST_24_MEAN         NaN
# Name: TARGET, Length: 110, dtype: float64
